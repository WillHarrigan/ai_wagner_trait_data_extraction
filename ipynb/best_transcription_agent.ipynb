# %%
from enum import Enum
from typing import Optional, List
import os
from openai import OpenAI
import json
import asyncio
import base64
import pandas as pd
import numpy as np
import sys
sys.path.append('/Users/williamharrigan/Desktop/UH/Year_3/semester_2/wagner')
import creds
import glob
import random

## pydantic
from pydantic import BaseModel, Field
from openai.lib._pydantic import to_strict_json_schema
from pydantic_ai import Agent
from openai.types.chat.chat_completion_content_part_param import (
    ChatCompletionContentPartTextParam,
    ChatCompletionContentPartImageParam
)

from openai.types.chat.chat_completion_content_part_image_param import (
    ImageURL
)

photo_dir = "../training_set/"

# %%
# photo_list = [i.split('/')[2].strip('.jpeg') for i in glob.glob(f'{photo_dir}*')]
# random_photo = random.sample(photo_list, 1)[0]
# random_photo

# %%
# ## Input to base64 format to be intepreted by extraction agents (chatbots)
# with open(f"{photo_dir}/{random_photo}.jpeg", "rb") as image_file:
#             base64_image = base64.b64encode(image_file.read()).decode("utf-8")

# %%
# image_urls = [
#     f"data:image/png;base64,{base64_image}",
# ]

# %%
# o4_transcription_agent = Agent(
#     model="openai:gpt-4o",
#     result_type=str,
#     system_prompt = "You are a vision model capable of accurately performing OCR on an image. You are especially good at extracting numerical values and measurements.",
# )

# image_params = [
#     ChatCompletionContentPartImageParam(
#         type='image_url', 
#         image_url=ImageURL(url=url, detail='low')
#     ) for url in image_urls
# ]

# ## Setting chat prompt to 'user_prompt'
# msg_open_ai = [
#             ChatCompletionContentPartTextParam(text="Convert this to text. Don't miss any text. If you encounter special characters that you do not recognize, please transcribe as +.", type='text'),
#             *image_params
# ]

# ## Running data extraction
# r = await o4_transcription_agent.run(msg_open_ai)


# if len(r.data.split("---")) == 1:
#     text = r.data.split("---")[0]
# else:
#     text = r.data.split("---")[1]
# print(text)

# %%
class Description(str, Enum):
    DICOTS = "Dicots"
    MONOCOTS = "Monocots"
    CONIFERS = "Conifers"
    FERNS = "Ferns and fern allies"

class StemHairType(str, Enum):
    DENDRITIC = "DENDRITIC"
    GLABROUS = "GLABROUS"
    HIRSUTE = "HIRSUTE"
    HISPID = "HISPID"
    LEPIDOTE = "LEPIDOTE"
    PILOSE = "PILOSE"
    PUBERULENT = "PUBERULENT"
    STRIGOSE = "STRIGOSE"
    STELLATE = "STELLATE"
    TOMENTOSE = "TOMENTOSE"
    VILLOUS = "VILLOUS"
    GLAUCOUS = "GLAUCOUS"
    
class FruitType(str, Enum):
    ACHENE = "ACHENE"
    AGGREGATE = "AGGREGATE"
    ARTICLE = "ARTICLE"
    BERRY = "BERRY"
    CAPSULE = "CAPSULE"
    CARYOPSIS = "CARYOPSIS"
    DRUPE = "DRUPE"
    FOLLICLE = "FOLLICLE"
    LEGUME = "LEGUME"
    MERICARP = "MERICARP"
    MULTIPLE = "MULTIPLE"
    NUT = "NUT"
    PEPO = "PEPO"
    POME = "POME"
    SCHIZOCARP = "SCHIZOCARP"
    SILICLE = "SILICLE"
    SILIQUE = "SILIQUE"
    SYCONIUM = "SYCONIUM"
    
class LeafShapeType(str, Enum):
    ACEROSE = "ACEROSE"
    AWL_SHAPED = "AWL_SHAPED"
    GLADIATE = "GLADIATE"
    HASTATE = "HASTATE"
    CORDATE = "CORDATE"
    DELTOID = "DELTOID"
    LANCEOLATE = "LANCEOLATE"
    LINEAR = "LINEAR"
    ELLIPTIC = "ELLIPTIC"
    ENSIFORM = "ENSIFORM"
    LYRATE = "LYRATE"
    OBCORDATE = "OBCORDATE"
    FALCATE = "FALCATE"
    FLABELLATE = "FLABELLATE"
    OBDELTOID = "OBDELTOID"
    OBELLIPTIC = "OBELLIPTIC"
    OBLANCEOLATE = "OBLANCEOLATE"
    OBLONG = "OBLONG"
    PERFOLIATE = "PERFOLIATE"
    QUADRATE = "QUADRATE"
    OBOVATE = "OBOVATE"
    ORBICULAR = "ORBICULAR"
    RENIFORM = "RENIFORM"
    RHOMBIC = "RHOMBIC"
    OVAL = "OVAL"
    OVATE = "OVATE"
    ROTUND = "ROTUND"
    SAGITTATE = "SAGITTATE"
    PANDURATE = "PANDURATE"
    PELTATE = "PELTATE"
    SPATULATE = "SPATULATE"
    SUBULATE = "SUBULATE"

class StemHairs(str, Enum):
    DENDRITIC = "DENDRITIC"
    GLABROUS = "GLABROUS"

class PhyllotaxyType(str, Enum):
    ALTERNATE = "ALTERNATE"
    OPPOSITE = "OPPOSITE"
    WHORLED = "WHORLED"
    DECUSSATE = "DECUSSATE"
    DISTICHOUS = "DISTICHOUS"
    EQUITANT = "EQUITANT"
    TERNATE = "TERNATE"
    CAULINE = "CAULINE"

class InflorescenceType(str, Enum):
    CATKIN = "CATKIN"
    CYME = "CYME"
    HEAD = "HEAD"
    PANICLE = "PANICLE"
    RACEME = "RACEME"
    SPATHE_SPADIX = "SPATHE_SPADIX"
    THYRSE = "THYRSE"
    UMBEL = "UMBEL"
    VERTISCILLATE = "VERTISCILLATE"
    SOLITARY = "SOLITARY"
    SPIKE = "SPIKE"
    LANCEOLATE = "LANCEOLATE"
    GLOBOSE = "GLOBOSE"
    INVOLUCRE = "INVOLUCRE"
    CORYMBOSE = "CORYMBOSE"
    STROBILOID = "STROBILOID"

class LeafHairType(str, Enum):
    DENDRITIC = "DENDRITIC"
    GLABROUS = "GLABROUS"
    HIRSUTE = "HIRSUTE"
    HISPID = "HISPID"
    LEPIDOTE = "LEPIDOTE"
    PILOSE = "PILOSE"
    PUBERULENT = "PUBERULENT"
    STRIGOSE = "STRIGOSE"
    STELLATE = "STELLATE"
    TOMENTOSE = "TOMENTOSE"
    VILLOUS = "VILLOUS"
    GLAUCOUS = "GLAUCOUS"

class LeafType(str, Enum):
    SIMPLE = "SIMPLE"
    COMPOUND = "COMPOUND"

class BreedingType(str, Enum):
    MONOECIOUS = "MONOECIOUS"  # Male and female flowers on the same plant
    ANDROMONOECIOUS = "ANDROMONOECIOUS"
    CHASMOGAMOUS = "CHASMOGAMOUS"
    DIOECIOUS = "DIOECIOUS"  # Separate male and female plants
    GYNODIOECIOUS = "GYNODIOECIOUS"
    POLYGAMO_MONOECIOUS = "POLYGAMO-MONOECIOUS"
    POLYGAMOUS = "POLYGAMOUS"
    POLYGAMO_DIOECIOUS = "POLYGAMO-DIOECIOUS"
    GYNOMONOECIOUS = "GYNOMONOECIOUS"
    STERILE = "STERILE"

class LeafMarginType(str, Enum):
    TEETH = "TEETH"
    LOBED = "LOBED"
    ENTIRE = "ENTIRE"
    NOTEETH = "NO TEETH"


class LifeFormType(str, Enum):
    ANNUAL_HERB = "ANNUAL_HERB"
    PERENNIAL_HERB = "PERENNIAL_HERB"
    EPIPHYTE = "EPIPHYTE"
    VINE = "VINE"
    SHRUB = "SHRUB"
    TREE = "TREE"

class CorollaType(str, Enum):
    ADNATE = "ADNATE"
    BILABIATE = "BILABIATE"
    CAMPANULATE = "CAMPANULATE"
    CORYMBOSE = "CORYMBOSE"
    CONVOLUTE = "CONVOLUTE"
    CORONA = "CORONA"
    CUNEATE = "CUNEATE"
    CYLINDRICAL = "CYLINDRICAL"
    DISK = "DISK"
    DELTATE = "DELTATE"
    ELLIPTIC = "ELLIPTIC"
    FUNNELFORM = "FUNNELFORM"
    FLABELLATE = "FLABELLATE"
    FILIFORM = "FILIFORM"
    HOOD = "HOOD"
    IRREGULAR = "IRREGULAR"
    KEEL = "KEEL"
    LABELLUM = "LABELLUM"
    LANCEOLATE = "LANCEOLATE"
    LINEAR = "LINEAR"
    LIPPED = "LIPPED"
    LOBBED = "LOBBED"
    OVATE = "OVATE"
    OBLONG = "OBLONG"
    OBCORDATE = "OBCORDATE"
    OBOVATE = "OBOVATE"
    OBLANCEOLATE = "OBLANCEOLATE"
    ORBICULAR = "ORBICULAR"
    PALATE = "PALATE"
    PSEUDORACEMES = "PSEUDORACEMES"
    ROTATE = "ROTATE"
    RAY = "RAY"
    REFLEXED = "REFLEXED"
    RHOMBIC = "RHOMBIC"
    RENIFORM = "RENIFORM"
    SALVERFORM = "SALVERFORM"
    SUBORBICULAR = "SUBORBICULAR"
    SUBRHOMBIC = "SUBRHOMBIC"
    SPUR = "SPUR"
    SPATULATE = "SPATULATE"
    SPICATE = "SPICATE"
    SUBROTATE = "SUBROTATE"
    STANDARD = "STANDARD"
    TUBULAR = "TUBULAR"
    TRIANGULAR = "TRIANGULAR"
    URCEOLATE = "URCEOLATE"
    UNILABIATE = "UNILABIATE"
    VALVATE = "VALVATE"
    VERTICIL = "VERTICIL"
    ZYGOMORPHIC = "ZYGOMORPHIC"
    CUP = "CUP"
    UNGUICULATE = "UNGUICULATE"
    CLAW = "CLAW"
    FASICLE = "FASICLE"
    STELLATE = "STELLATE"
    SUBPANICULATE = "SUBPANICULATE"
    PENTAGONAL = "PENTAGONAL"

class OriginType(str, Enum):
    NATURALIZED = "NATURALIZED"
    INDIGENOUS = "INDIGENOUS"
    ENDEMIC = "ENDEMIC"
    POLYNESIAN_INTRODUCTION = "POLYNESIAN INTRODUCTION"

class Location(str, Enum):
    HAWAII = "HAWAII"
    MAUI = "MAUI"
    KAHOOLAWE = "KAHOOLAWE"
    MOLOKAI = "MOLOKAI"
    LANAI = "LANAI"
    OAHU = "OAHU"
    KAUAI = "KAUAI"
    NIIHAU = "NIIHAU"
    ALL_ISLANDS = "ALL ISLANDS"

class FederalStatusType(str, Enum):
    SPECIES_OF_CONCERN = "SPECIES_OF_CONCERN"
    ENDANGERED = "ENDANGERED"
    THREATENED = "THREATENED"
    WITHDRAWN = "WITHDRAWN" 
    
class StatusType(str, Enum):
    NATURALIZED = "NATURALIZED"
    ENDEMIC = "ENDEMIC"
    RARE = "RARE"
    SECURE = "SECURE"
    VULNERABLE = "VULNERABLE"

class Measurements(BaseModel):
    min: Optional[float] = None
    max: Optional[float] = None
    extreme_min: Optional[float] = None
    extreme_max: Optional[float] = None

class HawaiianPlant(BaseModel):
    # Basic Information
    family: str = Field(..., description="Plant family name (should only be 1 object)")
    genus: str = Field(..., description="Plant genus name (should only be 1 object)")
    species: str = Field(..., description="Plant species name (should only be 1 object)")
    common_name: Optional[str] = Field(None, description="Common name of the plant")
    wagner_pg_number: Optional[str] = Field(None, description="Wagner book reference number")
    description: Optional[Description] = Field(None, description="Take knowledge from outside the passage to infer whether the plant is DICOTS, MONOCOTS, CONIFERS or FERNS")
    infraspecific_epithet: str = Field(..., description="The third word in the scientific name of an infraspecific taxon, following the name of the species. This applies only to formal names of plants and fungi, and not to the formal names of bacteria or animals. In the name Cannabis sativa subsp. indica, the word indica is the infraspecific epithet.")

    hawaiian_name: Optional[List[str]] = Field(None, description="List of Hawaiian names")
    
    stem_hair_type: Optional[StemHairType] = Field(None, description="Type of hair on stem")
    
    phyllotaxy_type: Optional[PhyllotaxyType] = Field(None, description="The arrangement of leaves around the stem.")

    leaf_hair_description: Optional[str] = Field(None, description="Description of leaf hair.")
    leaf_hair_upper_description: Optional[str] = Field(None, description="Description of Upper leaf hairs.")
    leaf_hair_lower_description: Optional[str] = Field(None, description="Description of Lower leaf hairs.")
    
    breeding_type: Optional[BreedingType] = Field(None, description="Plant reproductive class.")
    
    inflorescence_type: Optional[InflorescenceType] = Field(None, description="In a flowering plant, a cluster of flowers on a branch or a system of branches")
    
    ray_color: Optional[str] = Field(None, description="Color of ray")
    floret_color: Optional[str] = Field(None, description="Color of florets")
    spathe_color: Optional[str] = Field(None, description="Color of spathe")
    perianth_outer_color: Optional[str] = Field(None, description="Color of perianth outer flower")
    perianth_inner_color: Optional[str] = Field(None, description="Color of perianth inner flower")
    perianth_color: Optional[str] = Field(None, description="Color of perianth")
    labellum_color: Optional[str] = Field(None, description="Color of labellum")

    corolla_type: Optional[CorollaType] = Field(None, description="Type of corolla")
    corolla_color: Optional[str] = Field(None, description="Color of corolla")
    staminate_corolla_type: Optional[CorollaType] = Field(None, description="Type of staminate corolla")
    pistillate_corolla_type: Optional[CorollaType] = Field(None, description="Type of pistillate corolla")
    
    fruit_type: Optional[FruitType] = Field(None, description="Type of fruit")
    fruit_length: Optional[Measurements] = Field(None, description="Fruit length in millimeters")
    fruit_width: Optional[Measurements] = Field(None, description="Fruit width in millimeters")
    fruit_diameter: Optional[Measurements] = Field(None, description="Fruit diameter in millimeters")
    
    ploidy: Optional[str] = Field(None, description="Ploidy level expressed as a function of n (e.g., 1n, 2n or 3n, etc..)")
    chromosome_number: Optional[int] = Field(None, description="The integer Number of chromosomes")
    average_chromosome_number: Optional[float] = Field(None, description="Average chromosome number")
    
    origin: Optional[OriginType] = Field(None, description="Origin type of the plant")
    fed_status: Optional[FederalStatusType] = Field(None, description="Federal conservation status")
    status: Optional[StatusType] = Field(None, description="General status")

    life_form_type: Optional[LifeFormType] = Field(None, description="Growth habit or life form")
    leaf_type: Optional[LeafType] = Field(None, description="Simple or compound leaf type")
    leaf_shape_type: Optional[LeafShapeType] = Field(None, description="Shape of leaves")
    leaf_margin_type: Optional[LeafMarginType] = Field(None, description="Type of leaf margin")
    
    juvenile_leaf_type: Optional[LeafType] = Field(None, description="Simple or compound juvenile leaf type")
    juvenile_leaf_shape_type: Optional[LeafShapeType] = Field(None, description="Shape of juvenile leaves")
    juvenile_leaf_margin_type: Optional[LeafMarginType] = Field(None, description="Type of leaf margin on juvenile plants")
    
    leaflets_leaf_type: Optional[LeafType] = Field(None, description="Simple or compound juvenile leaf type")
    leaflets_leaf_shape_type: Optional[LeafShapeType] = Field(None, description="Shape of juvenile leaves")
    leaflets_leaf_margin_type: Optional[LeafMarginType] = Field(None, description="Type of leaf margin on juvenile plants")
    
    leaf_hair_upper_type: Optional[LeafHairType] = Field(None, description="Type of upper leaf hairs")
    leaf_hair_lower_type: Optional[LeafHairType] = Field(None, description="Type of lower leaf hairs")
    leaf_hair_type: Optional[LeafHairType] = Field(None, description="Type of leaf hairs")
    juvenile_leaf_hair_type: Optional[LeafHairType] = Field(None, description="Type of juvenile leaf hairs")
    
    island_type: Optional[List[Location]] = Field(None, description="Islands where the plant is found")
    
    stem_height: Optional[Measurements] = Field(None, description="Stem or general plant height measurements in meters")
    leaf_length: Optional[Measurements] = Field(None, description="Length of leaves in millimeters")
    leaf_width: Optional[Measurements] = Field(None, description="Width of leaves in millimeters")
    juvenile_leaf_length: Optional[Measurements] = Field(None, description="Juvenile length of leaves in millimeters")
    juvenile_leaf_width: Optional[Measurements] = Field(None, description="Juvenile width of leaves in millimeters")
    leaflets_leaf_length: Optional[Measurements] = Field(None, description="Leaflets length of leaves in millimeters")
    leaflets_leaf_width: Optional[Measurements] = Field(None, description="Leaflets width of leaves in millimeters")    
    
    petioles: Optional[Measurements] = Field(None, description="Length of petiole stalk in centimeters") 
    staminate_inflorescence_length: Optional[Measurements] = Field(None, description="The measured length in millimeters of the male (pollen-producing) flower cluster. This specifically refers to catkins or other inflorescences containing only staminate (male) flowers.")    
    pistillate_inflorescence_length: Optional[Measurements] = Field(None, description="The measured length of the female (seed-producing) flower cluster. This specifically refers to inflorescences containing only pistillate (female) flowers.")    
    staminate_inflorescence_width: Optional[Measurements] = Field(None, description="The measured width in millimeters of the male (pollen-producing) flower cluster. This specifically refers to catkins or other inflorescences containing only staminate (male) flowers.")    
    pistillate_inflorescence_width: Optional[Measurements] = Field(None, description="The measured width of the female (seed-producing) flower cluster. This specifically refers to inflorescences containing only pistillate (female) flowers.")        
    
    inflorescence_flower_length: Optional[Measurements] = Field(None, description="The length of an inflorescence flower in millimeters.")
    inflorescence_flower_width: Optional[Measurements] = Field(None, description="The width of an inflorescence flower in millimeters.")
    
    flower_length: Optional[Measurements] = Field(None, description="Flower length in centimeters")
    flower_width: Optional[Measurements] = Field(None, description="Flower width in centimeters")
    
    rachis_length: Optional[Measurements] = Field(None, description="Rachis length in millimeters")
    rachis_diameter: Optional[Measurements] = Field(None, description="Rachis diameter in millimeters") 
    
    head_length: Optional[Measurements] = Field(None, description="The measured length of the capitulum (flower head) in millimeters.")
    head_diameter: Optional[Measurements] = Field(None, description="The measured diameters of the capitulum (flower head) in millimeters.")
    
    bur_length: Optional[Measurements] = Field(None, description="The measured length of the bur in millimeters.")
    tepal_length: Optional[Measurements] = Field(None, description="The measured length of the tepal in millimeters.")
    staminate_tepal_length: Optional[Measurements] = Field(None, description="The measured length of the staminate tepal in millimeters.")
    pistillate_tepal_length: Optional[Measurements] = Field(None, description="The measured length of the pistillate tepal in millimeters.")
      
    ray_length: Optional[Measurements] = Field(None, description="The measured length of the ray in millimeters.")
    ray_width: Optional[Measurements] = Field(None, description="The measured width of the ray in millimeters.")
    
    florets_length: Optional[Measurements] = Field(None, description="The measured length of the florets in millimeters.")
    
    involucre_length: Optional[Measurements] = Field(None, description="Involucre length in millimeters")
    involucre_width: Optional[Measurements] = Field(None, description="Involucre width in millimeters")
    staminate_involucre_length: Optional[Measurements] = Field(None, description="Staminate involucre length in millimeters")
    pistilate_involucre_length: Optional[Measurements] = Field(None, description="Pistillate involucre length in millimeters")   
    
    bract_length: Optional[Measurements] = Field(None, description="Bract length in millimeters")
    bract_width: Optional[Measurements] = Field(None, description="Bract width in millimeters")
    bract_lower_length: Optional[Measurements] = Field(None, description="Lower bract length in millimeters")
    bract_outer_length: Optional[Measurements] = Field(None, description="Outer bract length in millimeters")
    
    bracteoles_length: Optional[Measurements] = Field(None, description="Bracteoles length in millimeters")
    bracteoles_width: Optional[Measurements] = Field(None, description="Bracteole width in millimeters")
    
    pedicel_length: Optional[Measurements] = Field(None, description="Pedicel length in millimeters")
    pedicel_width: Optional[Measurements] = Field(None, description="Pedicel width in millimeters")
    staminate_pedicel_length: Optional[Measurements] = Field(None, description="Staminate pedicel length in millimeters")
    pistillate_pedicel_length: Optional[Measurements] = Field(None, description="Pistillate pedicel length in millimeters")
    staminate_pedicel_width: Optional[Measurements] = Field(None, description="Staminate pedicel width in millimeters")
    pistillate_pedicel_width: Optional[Measurements] = Field(None, description="Pistillate pedicel width in millimeters") 
    
    hypanthium_length: Optional[Measurements] = Field(None, description="Hypanthium length in millimeters")
    hypanthium_width: Optional[Measurements] = Field(None, description="Hypanthium width in millimeters")
    
    peduncle_length: Optional[Measurements] = Field(None, description="Peduncle length in millimeters")
    peduncle_width: Optional[Measurements] = Field(None, description="Peduncle width in millimeters")
    staminate_peduncle_length: Optional[Measurements] = Field(None, description="Staminate peduncle length in millimeters")
    staminate_peduncle_width: Optional[Measurements] = Field(None, description="Staminate peduncle width in millimeters")
    pistillate_peduncle_length: Optional[Measurements] = Field(None, description="Pistillate peduncle length in millimeters")
    pistillate_peduncle_width: Optional[Measurements] = Field(None, description="Pistillate peduncle width in millimeters")

    spathe_width: Optional[Measurements] = Field(None, description="Spathe width dimensions in millimeters")
    spathe_length: Optional[Measurements] = Field(None, description="Spathe length dimensions in millimeters")
    spadix_length: Optional[Measurements] = Field(None, description="Spadix length dimensions in millimeters")
    
    perianth_width: Optional[Measurements] = Field(None, description="Perianth width dimensions in millimeters")
    perianth_length: Optional[Measurements] = Field(None, description="Perianth length dimensions in millimeters")   
    perianth_outer_width: Optional[Measurements] = Field(None, description="Outer perianth width dimensions in millimeters")
    perianth_outer_length: Optional[Measurements] = Field(None, description="Outer perianth length dimensions in millimeters") 
    perianth_inner_width: Optional[Measurements] = Field(None, description="Inner perianth width dimensions in millimeters")
    perianth_inner_length: Optional[Measurements] = Field(None, description="Inner perianth length dimensions in millimeters") 
    
    perianth_lobes_width: Optional[Measurements] = Field(None, description="Perianth lobes width dimensions in millimeters")
    perianth_lobes_length: Optional[Measurements] = Field(None, description="Perianth lobes length dimensions in millimeters") 
    perianth_tube_length: Optional[Measurements] = Field(None, description="Perianth tube length dimensions in millimeters") 
    pistillate_perianth_tube_length: Optional[Measurements] = Field(None, description="Pistillate perianth tube length dimensions in millimeters") 
    staminate_perianth_tube_length: Optional[Measurements] = Field(None, description="Staminate perianth tube length dimensions in millimeters") 
    
    pappus_length: Optional[Measurements] = Field(None, description="Pappus length in millimeters")
    umbellet_length: Optional[Measurements] = Field(None, description="Umbellet length in millimeters")
    labellum_width: Optional[Measurements] = Field(None, description="Labellum width dimensions in millimeters")
    labellum_length: Optional[Measurements] = Field(None, description="Labellum length dimensions in millimeters")
    
    calyx_length: Optional[Measurements] = Field(None, description="Calyx length in millimeters")
    calyx_width: Optional[Measurements] = Field(None, description="Calyx width in millimeters")
    calyx_teeth_length: Optional[Measurements] = Field(None, description="Calyx teeth length in millimeters")
    calyx_teeth_width: Optional[Measurements] = Field(None, description="Calyx teeth width in millimeters")
    calyx_lobes_length: Optional[Measurements] = Field(None, description="Calyx lobe length in millimeters")
    calyx_lobes_width: Optional[Measurements] = Field(None, description="Calyx lobe width in millimeters")
    
    upper_calyx_length: Optional[Measurements] = Field(None, description="Upper calyx length in millimeters")
    lower_calyx_length: Optional[Measurements] = Field(None, description="Lower calyx length in millimeters")
    
    inner_calyx_lobes_length: Optional[Measurements] = Field(None, description="Inner calyx lobes length in millimeters")
    inner_calyx_lobes_width: Optional[Measurements] = Field(None, description="Inner calyx lobes width in millimeters")
    outer_calyx_lobes_length: Optional[Measurements] = Field(None, description="Outer calyx lobes length in millimeters")
    outer_calyx_lobes_width: Optional[Measurements] = Field(None, description="Outer calyx lobes width in millimeters")
    
    calyx_tube_length: Optional[Measurements] = Field(None, description="Calyx tube length in millimeters")
    calyx_tube_width: Optional[Measurements] = Field(None, description="Calyx tube width in millimeters")
    
    male_calyx_length: Optional[Measurements] = Field(None, description="Male calyx length in millimeters")
    male_calyx_width: Optional[Measurements] = Field(None, description="Male calyx width in millimeters")
    
    male_calyx_lobes_length: Optional[Measurements] = Field(None, description="Male calyx length in millimeters")
    male_calyx_lobes_width: Optional[Measurements] = Field(None, description="Male calyx width in millimeters")
    
    female_calyx_length: Optional[Measurements] = Field(None, description="female calyx length in millimeters")
    female_calyx_width: Optional[Measurements] = Field(None, description="female calyx width in millimeters")
    
    female_calyx_lobes_length: Optional[Measurements] = Field(None, description="Female calyx length in millimeters")
    female_calyx_lobes_width: Optional[Measurements] = Field(None, description="Female calyx width in millimeters")
    
    male_calyx_lobes_length_inner: Optional[Measurements] = Field(None, description="Male calyx inner lobe length in millimeters")
    male_calyx_lobes_length_outer: Optional[Measurements] = Field(None, description="Male calyx outer length in millimeters")
    female_calyx_lobes_length_inner: Optional[Measurements] = Field(None, description="Female calyx inner lobe length in millimeters")
    female_calyx_lobes_length_outer: Optional[Measurements] = Field(None, description="Female calyx outer length in millimeters")
    
    male_calyx_lobes_width_outer: Optional[Measurements] = Field(None, description="Male calyx outer lobe width in millimeters")
    male_calyx_tube_length: Optional[Measurements] = Field(None, description="Male calyx tube length in millimeters")

    female_calyx_lobes_width_inner: Optional[Measurements] = Field(None, description="Female calyx inner lobe width in millimeters")
    female_calyx_lobes_width_outer: Optional[Measurements] = Field(None, description="Female calyx outer lobe width in millimeters")
    female_calyx_tube_length: Optional[Measurements] = Field(None, description="Female calyx tube length in millimeters")
    
    inner_calyx_length: Optional[Measurements] = Field(None, description="Inner calyx length in millimeters")
    outer_calyx_length: Optional[Measurements] = Field(None, description="Outer calyx length in millimeters")

    corolla_length: Optional[Measurements] = Field(None, description="Corolla length in millimeters")
    corolla_width: Optional[Measurements] = Field(None, description="Corolla width in millimeters")
    
    corolla_length: Optional[Measurements] = Field(None, description="Corolla length in millimeters")
    corolla_width: Optional[Measurements] = Field(None, description="Corolla width in millimeters")
    corolla_tube_length: Optional[Measurements] = Field(None, description="Corolla tube length in millimeters")
    corolla_tube_width: Optional[Measurements] = Field(None, description="Corolla tube width in millimeters")
    corolla_lobes_length: Optional[Measurements] = Field(None, description="Corolla lobes length in millimeters")
    corolla_lobes_width: Optional[Measurements] = Field(None, description="Corolla lobes width in millimeters")
    
    
    upper_corolla: Optional[Measurements] = Field(None, description="Upper corolla length in millimeters")
    lower_corolla: Optional[Measurements] = Field(None, description="Lower corolla length in millimeters")
    upper_corolla_lobes_length: Optional[Measurements] = Field(None, description="Upper corolla lobes length in millimeters")
    lower_corolla_lobes_length: Optional[Measurements] = Field(None, description="Lower corolla lobes length in millimeters")
    
    corolla_lip: Optional[Measurements] = Field(None, description="Corolla lip length in millimeters")
    
    staminate_corolla_length: Optional[Measurements] = Field(None, description="Staminate corolla length in millimeters")
    pistillate_corolla_length: Optional[Measurements] = Field(None, description="Pistillate corolla length in millimeters")
    
    staminate_corolla_tube_length: Optional[Measurements] = Field(None, description="Staminate corolla tube length in millimeters")
    pistillate_corolla_tube_length: Optional[Measurements] = Field(None, description="Pistillate corolla tube length in millimeters")

    staminate_corolla_tube_width: Optional[Measurements] = Field(None, description="Staminate corolla tube length in millimeters")
    pistillate_corolla_tube_width: Optional[Measurements] = Field(None, description="Pistillate corolla tube length in millimeters")    
    
    female_corolla_lobes_length: Optional[Measurements] = Field(None, description="Female corolla lobes length in millimeters") 
    female_corolla_lobes_width:  Optional[Measurements] = Field(None, description="Female corolla lobes width in millimeters") 
    male_corrola_lobes_length: Optional[Measurements] = Field(None, description="Male corolla lobes length in millimeters") 
    male_corrola_lobes_width: Optional[Measurements] = Field(None, description="Male corolla lobes width in millimeters") 
    
    fruit_length: Optional[Measurements] = Field(None, description="Fruit length in centimeters") 
    fruit_width: Optional[Measurements] = Field(None, description="Fruit width in centimeters") 
    fruit_diameter: Optional[Measurements] = Field(None, description="Fruit diameter in centimeters") 
    
    
    seeds_perfruit: Optional[Measurements] = Field(None, description="Number of seeds per fruit") 
    
    seed_length: Optional[Measurements] = Field(None, description="Seed length in centimeters") 
    seed_width: Optional[Measurements] = Field(None, description="Seed width in centimeters") 
    seed_diameter: Optional[Measurements] = Field(None, description="Seed diameter in centimeters")

# %%
# # family = 'Araliaceae'
# # genus = 'Cheirodendron'
# # species = 'forbesii'

# # ## Input to base64 format to be intepreted by extraction agents (chatbots)
# # with open(f"{photo_dir}/{family}_{genus}_{species}.jpeg", "rb") as image_file:
# #             base64_image = base64.b64encode(image_file.read()).decode("utf-8")

# photo_list = [i.split('/')[2].strip('.jpeg') for i in glob.glob(f'{photo_dir}*')]
# random_photo = random.sample(photo_list, 1)[0]
# # random_photo

# ## Input to base64 format to be intepreted by extraction agents (chatbots)
# with open(f"{photo_dir}/{random_photo}.jpeg", "rb") as image_file:
#             base64_image = base64.b64encode(image_file.read()).decode("utf-8")
            
# ## Setting the overall framework for how the extraction agent operates across all interactions
# system_prompt  = """
# You are an expert plant taxonomist. Please analyze this image and return the details according to the schema provided.
# You are exhaustive; you include ALL the details mentioned. Do not make any assumptions about the data and do not try to
# interpret what is not obvious from the text. When extracting information, ensure that you return a structured response in JSON format matching the `HawaiianPlant` schema. """

# ## Prompt to set specific focus for each extraction agent interaction (can be dynamic as need be)
# user_prompt= "Transcribe the plant information you see in this image"

# ## Setting extraction agent to be gpt-4o
# ## System prompt is being set to specifically transcribe information
# openai_img_to_text_transcription_agent = Agent(
#     model="openai:gpt-4o",
#     result_type=str,
#     system_prompt = "You are a vision model capable of accurately performing OCR on an image",
# )

# ## Data to be extracted from input image
# image_urls = [
#     f"data:image/png;base64,{base64_image}",
# ]

# ## Setting chat parameters: low detail (for efficiency) from input image
# image_params = [
#     ChatCompletionContentPartImageParam(
#         type='image_url', 
#         image_url=ImageURL(url=url, detail='low')
#     ) for url in image_urls
# ]

# ## Setting chat prompt to 'user_prompt'
# msg_open_ai = [
#             ChatCompletionContentPartTextParam(text="Convert this to text. Don't miss any text.", type='text'),
#             *image_params
# ]

# ## Running data extraction
# r = await openai_img_to_text_transcription_agent.run(msg_open_ai)

# ## Output to 'text'

# if len(r.data.split("---")) == 1:
#     text = r.data.split("---")[0]
# else:
#     text = r.data.split("---")[1]
# # print(text)

# ## Setting extraction agent to be gpt-4o
# ## Extracted data will be formatted according to HawaiianPlant schema
# openai_extraction_agent = Agent(
#     model="openai:gpt-4o",
#     result_type=HawaiianPlant,
#     system_prompt = system_prompt,
# )

# ## Data to be extracted from input image
# image_urls = [
#     f"data:image/png;base64,{base64_image}",
# ]

# ## Setting chat parameters: low detail (for efficiency) from input image
# image_params = [
#     ChatCompletionContentPartImageParam(
#         type='image_url', 
#         image_url=ImageURL(url=url, detail='low')
#     ) for url in image_urls
# ]

# ## Setting chat prompt to 'user_prompt'
# msg_open_ai = [
#             ChatCompletionContentPartTextParam(text=user_prompt, type='text'),
#             *image_params
# ]

# ## Running data extraction
# r = await openai_extraction_agent.run(msg_open_ai)

# ## Setting results to 'gpt_4o_output'
# gpt_4o_output = r.data

# # print('Done: gpt_4o_output')

# ## Setting extraction agent to be Claude Sonnet model
# ## Extracted data will be formatted according to HawaiianPlant schema
# sonnet_extraction_agent = Agent(
#     model="anthropic:claude-3-5-sonnet-latest",
#     result_type=HawaiianPlant,
#     system_prompt = system_prompt,
#     model_settings = {'temperature': 0.2}

# )

# ## Setting context
# msg_claude = [
#     ChatCompletionContentPartTextParam(text=user_prompt, type='text'),
#                 {
#                     "type": "image",
#                     "source": {
#                         "type": "base64",
#                         "media_type": "image/jpeg",
#                         "data": f"{base64_image}",
#                     }
#                 },
    
# ]

# ## Extracting data from image
# r = await sonnet_extraction_agent.run(msg_claude)
# sonnet_output = r.data

# # print('Done: sonnet_output')


# ## Setting system prompt
# gptmini_extraction_agent = Agent(
#     model="openai:o3-mini",
#     result_type=HawaiianPlant,
#     system_prompt = system_prompt,
# )

# ## Extracting output from extracted text
# r = await gptmini_extraction_agent.run(text)

# ## Setting output
# gpt_mini_output = r.data

# # print('Done: miniGPT ')

# %%
df= pd.read_csv("/Users/williamharrigan/Desktop/Github/ai_wagner_trait_data_extraction/files/man_extract.csv")
df.columns = df.columns.str.lower()

codes = pd.read_csv('/Users/williamharrigan/Desktop/Github/ai_wagner_trait_data_extraction/files/wagner_codes.csv')
codes.columns = codes.columns.str.lower()

type_cols = [col for col in df.columns if '_type_' in col]
col_groups = {}
for col in type_cols:
    prefix = '_'.join(col.split('_')[:-1])
    # print(prefix)
    if prefix not in col_groups:
        col_groups[prefix] = []
    col_groups[prefix].append(col)
    # print(col)

# # Create new collapsed columns
for prefix, cols in col_groups.items():
    df[prefix] = df.apply(lambda row: [col.split('_')[-1].upper() for col in cols if row[col] == 1], axis=1)
    
# Drop the original type columns
df.drop(columns=type_cols, inplace=True)

df['hawaiian_name'] = df[['hawaiian_name_1', 'hawaiian_name_2', 'hawaiian_name_3', 'hawaiian_name_4']].apply(
    lambda row: {x for x in row if pd.notna(x)}, axis=1
)

# Drop original columns if needed
df.drop(columns=['hawaiian_name_1', 'hawaiian_name_2', 'hawaiian_name_3', 'hawaiian_name_4'], inplace=True)

def collapse_measurements(df):
    # Group columns by their base name (everything before _min, _max, etc.)
    base_columns = {}
    
    for col in df.columns:
        parts = col.split('_')
        if len(parts) > 2:
            suffix = parts[-1]
            if suffix in ['exmin', 'min', 'max', 'exmax']:
                base_name = '_'.join(parts[:-1])
                if base_name not in base_columns:
                    base_columns[base_name] = []
                base_columns[base_name].append(col)
    
    # Columns to copy directly (non-measurement columns)
    non_measurement_cols = [col for col in df.columns 
                           if not any(col in cols for cols in base_columns.values())]
    
    # Start with non-measurement columns
    result_df = df[non_measurement_cols].copy()
    
    # Process each group of measurement columns
    collapsed_data = {}
    
    for base_name, cols in base_columns.items():
        # Extract just the name without the unit
        name_parts = base_name.split('_')
        unit = name_parts[-1]
        col_name = '_'.join(name_parts[:-1])
        
        # Create dictionaries for each row
        collapsed_data[col_name] = []
        
        for _, row in df.iterrows():
            measurement_dict = {
                'exmin': row[f"{base_name}_exmin"] if f"{base_name}_exmin" in cols else None,
                'min': row[f"{base_name}_min"] if f"{base_name}_min" in cols else None,
                'max': row[f"{base_name}_max"] if f"{base_name}_max" in cols else None,
                'exmax': row[f"{base_name}_exmax"] if f"{base_name}_exmax" in cols else None,
                'unit': unit
            }
            collapsed_data[col_name].append(measurement_dict)
    
    # Convert to DataFrame and concatenate with result_df
    collapsed_df = pd.DataFrame(collapsed_data)
    result_df = pd.concat([result_df, collapsed_df], axis=1)
    
    return result_df

# Example usage
# df is your original dataframe with columns like stem_height_m_exmin, etc.
new_df = collapse_measurements(df)

# Function to create a mapping dictionary from the codes dataframe
def create_mapping_dict(df, column_name):
    mapping = {}
    for entry in df[column_name].dropna():
        if isinstance(entry, str) and '=' in entry:  # Ensure valid key-value pairs
            key, value = entry.split('=', 1)
            mapping[key.strip()] = value.strip().lower()
    return mapping

# Generate mapping dictionaries for each relevant column
mapping_dicts = {col: create_mapping_dict(codes, col) for col in codes.columns if col in new_df.columns}

# Function to apply the mapping to new_df
def map_values(value, mapping):
    if pd.isna(value):
        return value  # Keep NaNs unchanged
    if isinstance(value, str):
        split_values = value.split(' to ')  # Handle cases like "G to Hi"
        mapped_values = [mapping.get(v.strip(), v.strip()) for v in split_values]
        return ' to '.join(mapped_values)
    return value  # Return unchanged if it's not a string

# Apply mappings to new_df
for col in mapping_dicts:
    new_df[col] = new_df[col].astype(str).apply(lambda x: map_values(x, mapping_dicts[col]))

# %%
class AreAnntoationsEqual(BaseModel):
    are_equal: bool = Field(..., description="Are the two annotations equal")
    justification: str = Field(..., description="Justification of the propose value for are_equal. Justifications should be as concise as possible.")
    

## Setting the prompt and model for validation agent
validation_agent = Agent(
    model="groq:llama-3.3-70b-specdec",
    result_type=AreAnntoationsEqual,
    system_prompt = """You are an expert taxonomist. You are comparing the outcome of a manually extracted result versus an automatically extracted result. You need to compare the automatic results and determine whether the result is synonymous or equal the manual one; taking into consideration
    linguisitc and formatting nuances. Your answer is whether the two results are similar True/False and a justificaiton for your answer""",
)

## Models to compare
# models = ["gpt_4o_output", "gpt_mini_output", "sonnet_output", "deepseek_llama"]
models = ["gpt_4o_output", "gpt_mini_output", "sonnet_output"]

# %%
# family, genus, species = random_photo.split('_')

# %%
# family, genus, species = random_photo.split('_')

# ground_truth = new_df[(new_df['family'] == family) & 
#                       (new_df['genus'] == genus) & 
#                       (new_df['species'] == species)].to_dict(orient='records')[0]

# model_outputs = {}
# model_outputs['gpt_4o_output'] = dict(gpt_4o_output)
# model_outputs['gpt_mini_output'] = dict(gpt_mini_output)
# model_outputs['sonnet_output'] = dict(sonnet_output)

# %%
# import math

# for gt_key, gt_value in ground_truth.items():
#     if isinstance(gt_value, dict):
#         values = [gt_value.get(k) for k in ['exmin', 'min', 'max', 'exmax']]
#         if all(isinstance(v, float) and math.isnan(v) for v in values):
#             # print(f"Groundtruth {gt_key}: {gt_value}")
#             for model in model_outputs.keys():
#                 auto_value = model_outputs[model].get(gt_key, "N/A")
#             if auto_value == None:
#                 print(f"Model {model}: {auto_value} \t Accurate output: True (Both NaN)")

#     for model in model_outputs.keys():
#         auto_value = model_outputs[model].get(gt_key, "N/A")

#         user_prompt = f"""manually annotated {gt_key}: {gt_value} automatically annotated {gt_key}: {auto_value}"""
        
#         if gt_value == 'nan' and auto_value == 'None':
#             print(f"Model {model}: {auto_value} \t Accurate output: True (Both NaN)")
#         else:
#             try:
#                 result = await validation_agent.run(user_prompt)  # Ensure `await` is used correctly
#                 print(f"Model {model}: {auto_value} \t Accurate output: {result.data.are_equal}")
#                 print(f"Justification: {result.data.justification}")  # Print the justification
#             except Exception as e:
#                 print(f"Error processing model {model} for key {gt_key}: {e}")

#     print()

# %%
import base64
import glob
import random
import math
from typing import List

photo_dir = "../training_set/"

# %%
# Step 1: Extract text from image using GPT-4o
async def extract_text_from_image():
    ocr_agent = Agent(
        model="openai:gpt-4o",
        result_type=str,
        system_prompt="You are a vision model capable of accurately performing OCR on an image",
    )
    
    msg = [
        ChatCompletionContentPartTextParam(text="Convert this to text. Don't miss any text.", type='text'),
        image_param
    ]
    
    result = await ocr_agent.run(msg)
    
    # Handle text extraction with more robust parsing
    text = result.data
    if "---" in text:
        parts = text.split("---")
        return parts[1] if len(parts) > 1 else parts[0]
    return text

# Step 2: Process with multiple models in parallel
async def process_with_models(extracted_text):
    # Prepare the common image message for vision models
    vision_msg = [
        ChatCompletionContentPartTextParam(text=user_prompt, type='text'),
        image_param
    ]
    
    # Claude's message format is different
    claude_msg = [
        ChatCompletionContentPartTextParam(text=user_prompt, type='text'),
        {
            "type": "image",
            "source": {
                "type": "base64",
                "media_type": "image/jpeg",
                "data": base64_image,
            }
        }
    ]
    
    # Setup extraction agents
    gpt4o_agent = Agent(
        model="openai:gpt-4o",
        result_type=HawaiianPlant,
        system_prompt=system_prompt,
    )
    
    claude_agent = Agent(
        model="anthropic:claude-3-5-sonnet-latest",
        result_type=HawaiianPlant,
        system_prompt=system_prompt,
        model_settings={'temperature': 0.2}
    )
    
    mini_agent = Agent(
        model="openai:o3-mini",
        result_type=HawaiianPlant,
        system_prompt=system_prompt,
    )
    
    # Process with all models (could use asyncio.gather for true parallelism)
    gpt4o_result = await gpt4o_agent.run(vision_msg)
    claude_result = await claude_agent.run(claude_msg)
    mini_result = await mini_agent.run(extracted_text)
    
    return {
        "gpt_4o_output": gpt4o_result.data,
        "sonnet_output": claude_result.data,
        "gpt_mini_output": mini_result.data
    }

# Main execution function
async def extract_plant_data():
    extracted_text = await extract_text_from_image()
    results = await process_with_models(extracted_text)
    return results

# Example usage:
# results = await extract_plant_data()
# print(f"GPT-4o results: {results['gpt_4o_output']}")
# print(f"Claude Sonnet results: {results['sonnet_output']}")
# print(f"GPT Mini results: {results['gpt_mini_output']}")

# %%
# Select a random photo
photo_list = [i.split('/')[-1].strip('.jpeg') for i in glob.glob(f'{photo_dir}*.jpeg')]
random_photo = random.choice(photo_list)
print(random_photo)
# family, genus, species = random_photo.split('_')

# ground_truth = new_df[(new_df['family'] == family) & 
#                       (new_df['genus'] == genus) & 
#                       (new_df['species'] == species)].to_dict(orient='records')[0]

# model_outputs = {}
# model_outputs['gpt_4o_output'] = dict(gpt_4o_output)
# model_outputs['gpt_mini_output'] = dict(gpt_mini_output)
# model_outputs['sonnet_output'] = dict(sonnet_output)

# Convert image to base64
with open(f"{photo_dir}/{random_photo}.jpeg", "rb") as image_file:
    base64_image = base64.b64encode(image_file.read()).decode("utf-8")

# System prompt for extraction agents
system_prompt = """
You are an expert plant taxonomist. Please analyze this image and return the details according to the schema provided.
You are exhaustive; you include ALL the details mentioned. Do not make any assumptions about the data and do not try to
interpret what is not obvious from the text. When extracting information, ensure that you return a structured response in JSON format matching the `HawaiianPlant` schema. """

# User prompt
user_prompt = "Transcribe the plant information you see in this image"

# Image URL and parameters (defined once)
image_url = f"data:image/png;base64,{base64_image}"
image_param = ChatCompletionContentPartImageParam(
    type='image_url', 
    image_url=ImageURL(url=image_url, detail='low')
)


results = await extract_plant_data()
# Out:
# Apiaceae_Daucus_pusillus

# %%
family, genus, species = random_photo.split('_')

ground_truth = new_df[(new_df['family'] == family) & 
                      (new_df['genus'] == genus) & 
                      (new_df['species'] == species)].to_dict(orient='records')[0]

model_outputs = {}
model_outputs['gpt_4o_output'] = dict(results['gpt_4o_output'])
model_outputs['gpt_mini_output'] = dict(results['gpt_mini_output'])
model_outputs['sonnet_output'] = dict(results['sonnet_output'])

# %%
class AreAnntoationsEqual(BaseModel):
    are_equal: bool = Field(..., description="Are the two annotations equal. Be lenient with evaluations.")
    justification: str = Field(..., description="Justification of the propose value for are_equal. Justifications should be as concise as possible.")
    

## Setting the prompt and model for validation agent
validation_agent = Agent(
    # model="groq:llama-3.3-70b-specdec",
    model="openai:o3-mini",
    result_type=AreAnntoationsEqual,
    system_prompt = """You are an expert taxonomist. You are comparing the outcome of a manually extracted result versus an automatically extracted result. You need to compare the automatic results and determine whether the result is synonymous or equal the manual one; taking into consideration
    linguisitc and formatting nuances. Your answer is whether the two results are similar True/False and a justificaiton for your answer""",
)

## Models to compare
# models = ["gpt_4o_output", "gpt_mini_output", "sonnet_output", "deepseek_llama"]
models = ["gpt_4o_output", "gpt_mini_output", "sonnet_output"]

# %%
# for gt_key, gt_value in ground_truth.items():
#     print(f"\n--- Validating {gt_key} ---")
#     print(f"Ground truth {gt_key}: {gt_value}")

#     # Check if gt_value is NaN (either float NaN or dictionary with NaNs)
#     gt_is_nan = False

#     # Check if gt_value is a float NaN
#     if isinstance(gt_value, float) and math.isnan(gt_value):
#         gt_is_nan = True

#     # Check if gt_value is a string 'nan'
#     elif gt_value == 'nan':
#         gt_is_nan = True

#     # Check if gt_value is a dictionary with all NaN values
#     elif isinstance(gt_value, dict):
#         values = [gt_value.get(k) for k in ['exmin', 'min', 'max', 'exmax']]
#         gt_is_nan = all(isinstance(v, float) and math.isnan(v) for v in values if v is not None)

#     # Collect all model outputs for this key
#     model_results = {}
#     all_none_or_nan = True

#     for model, model_output in model_outputs.items():
#         auto_value = model_output.get(gt_key, "N/A")
#         model_results[model] = auto_value
        
#         # Check if any values are not None/nan
#         if not (auto_value is None or auto_value == 'None' or auto_value == 'nan'):
#             all_none_or_nan = False

#     # If ground truth is any type of NaN and all models returned None/nan values
#     if gt_is_nan:
#         for model, auto_value in model_results.items():
#             if auto_value is None or auto_value == 'None' or auto_value == 'nan':
#                 print(f"Model {model}: {auto_value} \t Accurate output: True (Both NaN)")
#             else:
#                 # Only validate non-None values against NaN ground truth
#                 try:
#                     user_prompt = f"""manually annotated {gt_key}: {gt_value} automatically annotated {gt_key}: {auto_value}"""
#                     result = await validation_agent.run(user_prompt)
#                     print(f"Model {model}: {auto_value}")
#                     print(f"Accurate output: {result.data.are_equal}")
#                     print(f"Justification: {result.data.justification}")
#                 except Exception as e:
#                     print(f"Error processing model {model} for key {gt_key}: {e}")
#         # Skip the rest of the processing for this key
#         continue

#     # For non-NaN ground truth values, proceed with normal validation
#     for model, auto_value in model_results.items():
#         try:
#             user_prompt = f"""manually annotated {gt_key}: {gt_value} automatically annotated {gt_key}: {auto_value}"""
#             result = await validation_agent.run(user_prompt)
#             print(f"Model {model}: {auto_value}")
#             print(f"Accurate output: {result.data.are_equal}")
#             print(f"Justification: {result.data.justification}")
#         except Exception as e:
#             print(f"Error processing model {model} for key {gt_key}: {e}")

# %%
import math

for gt_key, gt_value in ground_truth.items():
    print(f"\n--- Validating {gt_key} ---")
    print(f"Ground truth {gt_key}: {gt_value}")
    
    # Check if gt_value is NaN (either float NaN or dictionary with NaNs)
    gt_is_nan = False
    
    # Check if gt_value is a float NaN
    if isinstance(gt_value, float) and math.isnan(gt_value):
        gt_is_nan = True
    
    # Check if gt_value is a string 'nan'
    elif gt_value == 'nan':
        gt_is_nan = True
    
    # Check if gt_value is a dictionary with all NaN values
    elif isinstance(gt_value, dict):
        values = [gt_value.get(k) for k in ['exmin', 'min', 'max', 'exmax']]
        gt_is_nan = all(isinstance(v, float) and math.isnan(v) for v in values if v is not None)
    
    # Collect all model outputs for this key
    model_results = {}
    all_none_or_nan = True
    
    for model, model_output in model_outputs.items():
        auto_value = model_output.get(gt_key, "N/A")
        model_results[model] = auto_value
        
        # Check if any values are not None/nan
        if not (auto_value is None or auto_value == 'None' or auto_value == 'nan'):
            all_none_or_nan = False
    
    # Process based on whether ground truth is NaN or not
    if gt_is_nan:
        # For NaN ground truth, only print results for None/nan model outputs
        for model, auto_value in model_results.items():
            if auto_value is None or auto_value == 'None' or auto_value == 'nan':
                print(f"Model {model}: {auto_value} \t Accurate output: True (Both NaN)")
            else:
                # Only validate non-None values against NaN ground truth
                try:
                    user_prompt = f"""manually annotated {gt_key}: {gt_value} automatically annotated {gt_key}: {auto_value}"""
                    result = await validation_agent.run(user_prompt)
                    print(f"Model {model}: {auto_value}")
                    print(f"Accurate output: {result.data.are_equal}")
                    print(f"Justification: {result.data.justification}")
                except Exception as e:
                    print(f"Error processing model {model} for key {gt_key}: {e}")
    else:
        # For non-NaN ground truth values
        for model, auto_value in model_results.items():
            # If model output is None but ground truth is not NaN, mark as False without validation
            if auto_value is None or auto_value == 'None' or auto_value == 'nan':
                print(f"Model {model}: {auto_value} \t Accurate output: False (Ground truth exists but model returned None)")
            else:
                # Normal validation through the agent
                try:
                    user_prompt = f"""manually annotated {gt_key}: {gt_value} automatically annotated {gt_key}: {auto_value}"""
                    result = await validation_agent.run(user_prompt)
                    print(f"Model {model}: {auto_value}")
                    print(f"Accurate output: {result.data.are_equal}")
                    print(f"Justification: {result.data.justification}")
                except Exception as e:
                    print(f"Error processing model {model} for key {gt_key}: {e}")
# Out:
# --- Validating family ---
# Ground truth family: Apiaceae
# Model gpt_4o_output: Apiaceae
# Accurate output: True
# Justification: Both the manually and automatically annotated family are the same: 'Apiaceae'.
# Model gpt_mini_output: Apiaceae
# Accurate output: True
# Justification: Both manual and automatic annotations indicate the family as Apiaceae, making them synonymous.
# Model sonnet_output: Apiaceae
# Accurate output: True
# Justification: Both annotations identify the family as 'Apiaceae' with matching terminology and formatting.
#
# --- Validating genus ---
# Ground truth genus: Daucus
# Model gpt_4o_output: Daucus
# Accurate output: True
# Justification: Both annotations indicate the genus as 'Daucus', with no differences in naming or formatting.
# Model gpt_mini_output: Daucus
# Accurate output: True
# Justification: Both the manual and automated annotations indicate the same genus 'Daucus' with identical formatting.
# Model sonnet_output: Daucus
# Accurate output: True
# Justification: Both manual and automatic annotations specify the genus as 'Daucus', making them identical.
#
# --- Validating species ---
# Ground truth species: pusillus
# Model gpt_4o_output: pusillus
# Accurate output: True
# Justification: Both manually and automatically annotated species are exactly 'pusillus', making them equivalent.
# Model gpt_mini_output: pusillus
# Accurate output: True
# Justification: Both manual and automatic annotations are identical ('pusillus').
# Model sonnet_output: pusillus
# Accurate output: True
# Justification: Both the manual and automatic annotations are identical ('pusillus').
#
# --- Validating common_name ---
# Ground truth common_name: American carrot
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: American carrot
# Accurate output: True
# Justification: Both manual and automatic results list 'American carrot' as the common name, making them identical.
# Model sonnet_output: American carrot
# Accurate output: True
# Justification: Both the manually and automatically annotated common name are exactly 'American carrot'.
#
# --- Validating wagner_pg_number ---
# Ground truth wagner_pg_number: pg 203-204
# Model gpt_4o_output: 204
# Accurate output: False
# Justification: The manual annotation specifies a page range (pg 203-204) while the automatic annotation records only a single page (204), so they are not equivalent.
# Model gpt_mini_output: 204
# Accurate output: False
# Justification: The manual annotation indicates a page range (pg 203-204), while the automatic annotation identifies only a single page (204). This difference in scope makes the annotations not equivalent.
# Model sonnet_output: 204
# Accurate output: False
# Justification: The manual annotation indicates a range (pg 203-204) while the automatic annotation only contains a single page (204), so they are not equivalent.
#
# --- Validating description ---
# Ground truth description: Dicots
# Model gpt_4o_output: Dicots
# Accurate output: True
# Justification: Both annotations are identical: 'Dicots'.
# Model gpt_mini_output: Dicots
# Accurate output: True
# Justification: Both manual and automatic annotations exactly match the term 'Dicots'.
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating infraspecific_epithet ---
# Ground truth infraspecific_epithet: nan
# Model gpt_4o_output: Michx.
# Accurate output: False
# Justification: The manual annotation is 'nan' whereas the automatic annotation is 'Michx.', which are clearly different values.
# Model gpt_mini_output:
# Accurate output: True
# Justification: Both annotations indicate that there is no infraspecific epithet, with 'nan' reflecting a missing value and the automatic annotation being empty.
# Model sonnet_output: <UNKNOWN>
# Accurate output: True
# Justification: Both 'nan' and '<UNKNOWN>' are used to represent missing or undefined infraspecific epithet information, making them functionally equivalent.
#
# --- Validating stem_hair_type ---
# Ground truth stem_hair_type: puberulent
# Model gpt_4o_output: HISPID
# Accurate output: False
# Justification: The manual annotation 'puberulent' and the automatic annotation 'HISPID' refer to different types of hair covering. 'Puberulent' implies fine, short hairs, whereas 'hispid' indicates stiff, rough hairs, so they are not synonymous.
# Model gpt_mini_output: HISPID
# Accurate output: False
# Justification: The manually annotated 'puberulent' and the automatically annotated 'HISPID' are not synonymous; they describe different hair characteristics.
# Model sonnet_output: HISPID
# Accurate output: False
# Justification: The manual annotation 'puberulent' (having soft, short hairs) is not synonymous with 'hispid' (stiff, bristly hairs), hence they are not equivalent.
#
# --- Validating phyllotaxy_type ---
# Ground truth phyllotaxy_type: alternate
# Model gpt_4o_output: ALTERNATE
# Accurate output: True
# Justification: Both annotations refer to the same phyllotaxy type (alternate/ALTERNATE), differing only in capitalization.
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating leaf_hair_description ---
# Ground truth leaf_hair_description: pubescent
# Model gpt_4o_output: hispid
# Accurate output: False
# Justification: The manual annotation 'pubescent' typically implies soft, fine hairs, whereas 'hispid' indicates stiff or rough hairs. They are botanically distinct and not synonymous.
# Model gpt_mini_output: hispid
# Accurate output: False
# Justification: The manual annotation 'pubescent' (soft, fine hairs) and the automated 'hispid' (stiff, rough hairs) describe different hair textures, so they are not synonymous.
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating leaf_hair_upper_description ---
# Ground truth leaf_hair_upper_description: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating leaf_hair_lower_description ---
# Ground truth leaf_hair_lower_description: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating breeding_type ---
# Ground truth breeding_type: monoecious
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating inflorescence_type ---
# Ground truth inflorescence_type: umbel
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating ray_color ---
# Ground truth ray_color: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating floret_color ---
# Ground truth floret_color: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating spathe_color ---
# Ground truth spathe_color: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_outer_color ---
# Ground truth perianth_outer_color: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_inner_color ---
# Ground truth perianth_inner_color: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: white
# Accurate output: False
# Justification: The manual annotation indicates no value (nan) while the automatic annotation specifies 'white'. They are not equivalent.
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_color ---
# Ground truth perianth_color: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating labellum_color ---
# Ground truth labellum_color: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating corolla_type ---
# Ground truth corolla_type: obcordate
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating staminate_corolla_type ---
# Ground truth staminate_corolla_type: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_corolla_type ---
# Ground truth pistillate_corolla_type: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating corolla_color ---
# Ground truth corolla_color: White, occasionally center or all flowers purplish and yellowish
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating fruit_type ---
# Ground truth fruit_type: mericarp
# Model gpt_4o_output: SCHIZOCARP
# Accurate output: False
# Justification: The manual annotation 'mericarp' refers to a component of a schizocarp; the automatic 'SCHIZOCARP' indicates the entire fruit type. They represent different concepts and are not synonymous.
# Model gpt_mini_output: SCHIZOCARP
# Accurate output: False
# Justification: The manual annotation 'mericarp' refers to a single segment of a schizocarp, whereas 'SCHIZOCARP' refers to the entire fruit type, making them distinct.
# Model sonnet_output: MERICARP
# Accurate output: True
# Justification: The difference is only in capitalization; both annotations refer to the same taxon 'mericarp', hence they are equivalent.
#
# --- Validating ploidy ---
# Ground truth ploidy: 2n
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating chromosome_number ---
# Ground truth chromosome_number: 22
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: 22
# Accurate output: True
# Justification: Both the manually and automatically annotated chromosome_number values are exactly the same ('22'), showing no differences.
#
# --- Validating average_chromosome_number ---
# Ground truth average_chromosome_number: 22.0
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating origin ---
# Ground truth origin: NATU
# Model gpt_4o_output: NATURALIZED
# Accurate output: False
# Justification: The annotation 'NATU' does not equate to 'NATURALIZED'. Despite possible similarity in appearance, they differ in wording and likely meaning.
# Model gpt_mini_output: NATURALIZED
# Accurate output: True
# Justification: The abbreviation 'NATU' is understood to represent 'NATURALIZED', making both annotations equivalent.
# Model sonnet_output: INDIGENOUS
# Accurate output: True
# Justification: Both 'NATU' (interpreted as Native) and 'INDIGENOUS' refer to the original or native peoples, making them essentially synonymous in this context.
#
# --- Validating fed_status ---
# Ground truth fed_status: NS
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating status ---
# Ground truth status: nan
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating life_form_type ---
# Ground truth life_form_type: ['AH']
# Model gpt_4o_output: ANNUAL_HERB
# Accurate output: True
# Justification: The manual annotation 'AH' is a shorthand for 'ANNUAL_HERB', making the annotations effectively identical.
# Model gpt_mini_output: ANNUAL_HERB
# Accurate output: True
# Justification: The abbreviation 'AH' is equivalent to 'ANNUAL_HERB', making the automatic result synonymous with the manual annotation.
# Model sonnet_output: ANNUAL_HERB
# Accurate output: True
# Justification: The abbreviation 'AH' in the manual annotation corresponds to 'Annual Herb' in the automated annotation, making them semantically equivalent.
#
# --- Validating leaf_type ---
# Ground truth leaf_type: ['SIMPLE']
# Model gpt_4o_output: COMPOUND
# Accurate output: False
# Justification: The manual annotation is 'SIMPLE' (as an array), while the automatic annotation is 'COMPOUND', which are semantically different.
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating leaf_margin_type ---
# Ground truth leaf_margin_type: []
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating leaf_shape_type ---
# Ground truth leaf_shape_type: ['OBLO']
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: OBLONG
# Accurate output: True
# Justification: The manual annotation ‘OBLO’ is an abbreviated form of ‘OBLONG’, and both indicate the same leaf shape type.
#
# --- Validating juvenile_leaf_type ---
# Ground truth juvenile_leaf_type: []
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating juvenile_leaf_margin_type ---
# Ground truth juvenile_leaf_margin_type: []
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating juvenile_leaf_shape_type ---
# Ground truth juvenile_leaf_shape_type: []
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating leaflets_leaf_type ---
# Ground truth leaflets_leaf_type: []
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating leaflets_leaf_margin_type ---
# Ground truth leaflets_leaf_margin_type: []
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating leaflets_leaf_shape_type ---
# Ground truth leaflets_leaf_shape_type: []
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating leaf_hair_type ---
# Ground truth leaf_hair_type: ['HI']
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating leaf_hair_upper_type ---
# Ground truth leaf_hair_upper_type: []
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating leaf_hair_lower_type ---
# Ground truth leaf_hair_lower_type: []
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating juvenile_leaf_hair_type ---
# Ground truth juvenile_leaf_hair_type: []
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating island_type ---
# Ground truth island_type: ['H', 'MO', 'L', 'O', 'KAU']
# Model gpt_4o_output: [<Location.ALL_ISLANDS: 'ALL ISLANDS'>]
# Accurate output: False
# Justification: The manual annotation lists multiple specific island codes (H, MO, L, O, KAU) while the automatically generated annotation represents all islands via a single enum value (ALL ISLANDS), which are not equivalent.
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: [<Location.OAHU: 'OAHU'>, <Location.MOLOKAI: 'MOLOKAI'>, <Location.LANAI: 'LANAI'>, <Location.HAWAII: 'HAWAII'>]
# Accurate output: False
# Justification: The automatic result includes only four items and their mappings (Oahu, Molokai, Lanai, Hawaii) differ from the manual one which has five codes ('H', 'MO', 'L', 'O', 'KAU'). The 'KAU' code (likely representing Kauai) is missing.
#
# --- Validating hawaiian_name ---
# Ground truth hawaiian_name: set()
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating stem_height ---
# Ground truth stem_height: {'exmin': nan, 'min': 0.03, 'max': 0.9, 'exmax': nan, 'unit': 'm'}
# Model gpt_4o_output: min=None max=0.3 extreme_min=None extreme_max=0.6
# Accurate output: False
# Justification: The values differ significantly: manual min (0.03 vs. None) and manual max (0.9 vs. 0.3) are not aligned, and the extreme values (nan vs. None/0.6) and missing unit in the automatic annotation further contribute to the differences.
# Model gpt_mini_output: min=3.0 max=90.0 extreme_min=None extreme_max=None
# Accurate output: True
# Justification: The automatically annotated values (min=3.0, max=90.0) correspond to the manual stem_height values when converting from meters to centimeters (0.03 m = 3 cm, 0.9 m = 90 cm) and the missing extreme values (nan vs None) are considered equivalent.
# Model sonnet_output: min=0.03 max=0.9 extreme_min=None extreme_max=None
# Accurate output: True
# Justification: Both annotations indicate min=0.03, max=0.9, and use a null representation for extreme limits (nan vs None). The omission of 'unit' in the automatic annotation is a formatting nuance, so they are considered equivalent.
#
# --- Validating leaf_length ---
# Ground truth leaf_length: {'exmin': nan, 'min': 3.0, 'max': 10.5, 'exmax': nan, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: min=0.5 max=30.5 extreme_min=None extreme_max=None
# Accurate output: False
# Justification: The automatic result differs significantly from the manual one: the minimum and maximum values (0.5 vs 3.0 and 30.5 vs 10.5) do not match, and the unit is missing.
# Model sonnet_output: min=30.0 max=105.0 extreme_min=None extreme_max=None
# Accurate output: True
# Justification: Both annotations represent the same measurements. The manual annotation is in cm (3.0 cm to 10.5 cm), which converts to 30.0 to 105.0 in mm. The extreme values (nan vs None) are also equivalent.
#
# --- Validating leaf_width ---
# Ground truth leaf_width: {'exmin': nan, 'min': 1.5, 'max': 7.0, 'exmax': nan, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: min=1.5 max=7.0 extreme_min=None extreme_max=None
# Accurate output: True
# Justification: The key numeric boundaries match (min=1.5, max=7.0) and 'nan' is equated with None. The absence of unit information in the automatic version is a minor formatting difference.
# Model sonnet_output: min=15.0 max=70.0 extreme_min=None extreme_max=None
# Accurate output: False
# Justification: The automatic values are an order of magnitude larger than the manual ones (15.0 vs 1.5 and 70.0 vs 7.0) and lack the unit specification, hence they are not equivalent.
#
# --- Validating juvenile_leaf_length ---
# Ground truth juvenile_leaf_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating juvenile_leaf_width ---
# Ground truth juvenile_leaf_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating leaflets_leaf_length ---
# Ground truth leaflets_leaf_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating leaflets_leaf_width ---
# Ground truth leaflets_leaf_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating petioles ---
# Ground truth petioles: {'exmin': nan, 'min': 4.0, 'max': 15.0, 'exmax': nan, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: min=1.0 max=11.0 extreme_min=None extreme_max=None
# Accurate output: False
# Justification: The numerical values for min and max differ (manual: min=4.0, max=15.0 vs automatic: min=1.0, max=11.0) even though null fields match, and field names differ.
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating staminate_inflorescence_length ---
# Ground truth staminate_inflorescence_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating staminate_inflorescence_width ---
# Ground truth staminate_inflorescence_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_inflorescence_length ---
# Ground truth pistillate_inflorescence_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_inflorescence_width ---
# Ground truth pistillate_inflorescence_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating inflorescence_flower_length ---
# Ground truth inflorescence_flower_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating inflorescence_flower_width ---
# Ground truth inflorescence_flower_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating flower_length ---
# Ground truth flower_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating flower_width ---
# Ground truth flower_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating rachis_length ---
# Ground truth rachis_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating rachis_diameter ---
# Ground truth rachis_diameter: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating head_length ---
# Ground truth head_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating head_diameter ---
# Ground truth head_diameter: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating bur_length ---
# Ground truth bur_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating tepal_length ---
# Ground truth tepal_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating staminate_tepal_length ---
# Ground truth staminate_tepal_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_tepal_length ---
# Ground truth pistillate_tepal_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating ray_length ---
# Ground truth ray_length: {'exmin': nan, 'min': 4.0, 'max': 40.0, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating ray_width ---
# Ground truth ray_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating florets_length ---
# Ground truth florets_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating involucre_length ---
# Ground truth involucre_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating involucre_width ---
# Ground truth involucre_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating staminate_involucre_length ---
# Ground truth staminate_involucre_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistilate_involucre_length ---
# Ground truth pistilate_involucre_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating bract_length ---
# Ground truth bract_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating bract_width ---
# Ground truth bract_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating bract_lower_length ---
# Ground truth bract_lower_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating bract_outer_length ---
# Ground truth bract_outer_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating bracteoles_length ---
# Ground truth bracteoles_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating bracteoles_width ---
# Ground truth bracteoles_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pedicel_length ---
# Ground truth pedicel_length: {'exmin': nan, 'min': 2.0, 'max': 9.0, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: min=2.0 max=9.0 extreme_min=None extreme_max=None
# Accurate output: True
# Justification: Both annotations provide the same numerical values (min=2.0, max=9.0) and denote the absence of extreme values (nan equivalent to None). The missing unit in the automatic extraction is a formatting nuance.
#
# --- Validating pedicel_width ---
# Ground truth pedicel_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating staminate_pedicel_width ---
# Ground truth staminate_pedicel_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_pedicel_width ---
# Ground truth pistillate_pedicel_width: {'exmin': nan, 'min': None, 'max': None, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_pedicel_length ---
# Ground truth pistillate_pedicel_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating hypanthium_length ---
# Ground truth hypanthium_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating hypanthium_width ---
# Ground truth hypanthium_width: {'exmin': nan, 'min': None, 'max': None, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating peduncle_length ---
# Ground truth peduncle_length: {'exmin': nan, 'min': 110.0, 'max': 450.0, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: min=11.0 max=45.0 extreme_min=None extreme_max=None
# Accurate output: True
# Justification: The automatic values (min=11.0 and max=45.0) are exactly one-tenth of the manual values (min=110.0 and max=450.0), implying a unit conversion (mm to cm). The extreme values (nan vs None) are semantically equivalent.
#
# --- Validating peduncle_width ---
# Ground truth peduncle_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating staminate_peduncle_length ---
# Ground truth staminate_peduncle_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating staminate_peduncle_width ---
# Ground truth staminate_peduncle_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_peduncle_length ---
# Ground truth pistillate_peduncle_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_peduncle_width ---
# Ground truth pistillate_peduncle_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating spathe_length ---
# Ground truth spathe_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating spathe_width ---
# Ground truth spathe_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating spadix_length ---
# Ground truth spadix_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_length ---
# Ground truth perianth_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_width ---
# Ground truth perianth_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_outer_length ---
# Ground truth perianth_outer_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_outer_width ---
# Ground truth perianth_outer_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_inner_length ---
# Ground truth perianth_inner_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_inner_width ---
# Ground truth perianth_inner_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_tube_length ---
# Ground truth perianth_tube_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_lobes_length ---
# Ground truth perianth_lobes_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating perianth_lobes_width ---
# Ground truth perianth_lobes_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating staminate_perianth_tube_length ---
# Ground truth staminate_perianth_tube_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_perianth_tube_length ---
# Ground truth pistillate_perianth_tube_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pappus_length ---
# Ground truth pappus_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating umbellet_length ---
# Ground truth umbellet_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating labellum_length ---
# Ground truth labellum_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating labellum_width ---
# Ground truth labellum_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating calyx_length ---
# Ground truth calyx_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating calyx_width ---
# Ground truth calyx_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating calyx_teeth_length ---
# Ground truth calyx_teeth_length: {'exmin': nan, 'min': 0.1, 'max': 0.2, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: min=0.1 max=0.2 extreme_min=None extreme_max=None
# Accurate output: True
# Justification: Both annotations convey the same numerical values; 'exmin' (nan) is equivalent to 'extreme_min' (None) and 'exmax' (None) matches 'extreme_max' (None). The unit field omission in the automatic result is a formatting nuance, and overall, the two annotations are equivalent.
#
# --- Validating calyx_teeth_width ---
# Ground truth calyx_teeth_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating calyx_lobes_length ---
# Ground truth calyx_lobes_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating calyx_lobes_width ---
# Ground truth calyx_lobes_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating upper_calyx_length ---
# Ground truth upper_calyx_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# ...
# female_calyx_length_mm_max    NaN
# Name: 11, dtype: object, 'exmax': female_calyx_length_mm_exmax    NaN
# female_calyx_length_mm_exmax    NaN
# Name: 11, dtype: object, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating female_calyx_width ---
# Ground truth female_calyx_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating female_calyx_lobes_length ---
# Ground truth female_calyx_lobes_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating female_calyx_lobes_width ---
# Ground truth female_calyx_lobes_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating male_calyx_lobes_length_inner ---
# Ground truth male_calyx_lobes_length_inner: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating male_calyx_lobes_length_outer ---
# Ground truth male_calyx_lobes_length_outer: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating male_calyx_lobes_width_outer ---
# Ground truth male_calyx_lobes_width_outer: {'exmin': None, 'min': male_calyx_lobes_width_outer_mm_min    NaN
# male_calyx_lobes_width_outer_mm_min    NaN
# Name: 11, dtype: object, 'max': male_calyx_lobes_width_outer_mm_max    NaN
# male_calyx_lobes_width_outer_mm_max    NaN
# Name: 11, dtype: object, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model gpt_mini_output: None 	 Accurate output: False (Ground truth exists but model returned None)
# Model sonnet_output: None 	 Accurate output: False (Ground truth exists but model returned None)
#
# --- Validating male_calyx_tube_length ---
# Ground truth male_calyx_tube_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating female_calyx_lobes_length_inner ---
# Ground truth female_calyx_lobes_length_inner: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating female_calyx_lobes_length_outer ---
# Ground truth female_calyx_lobes_length_outer: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating female_calyx_lobes_width_inner ---
# Ground truth female_calyx_lobes_width_inner: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating female_calyx_lobes_width_outer ---
# Ground truth female_calyx_lobes_width_outer: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating inner_calyx_length ---
# Ground truth inner_calyx_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating outer_calyx_length ---
# Ground truth outer_calyx_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating corolla_length ---
# Ground truth corolla_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating corolla_width ---
# Ground truth corolla_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating corolla_tube_length ---
# Ground truth corolla_tube_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating corolla_tube_width ---
# Ground truth corolla_tube_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating corolla_lobes_length ---
# Ground truth corolla_lobes_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating corolla_lobes_width ---
# Ground truth corolla_lobes_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating upper_corolla ---
# Ground truth upper_corolla: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating lower_corolla ---
# Ground truth lower_corolla: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating upper_corolla_lobes_length ---
# Ground truth upper_corolla_lobes_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating lower_corolla_lobes_length ---
# Ground truth lower_corolla_lobes_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating corolla_lip ---
# Ground truth corolla_lip: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating staminate_corolla_length ---
# Ground truth staminate_corolla_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_corolla_length ---
# Ground truth pistillate_corolla_length: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating staminate_corolla_tube_length ---
# Ground truth staminate_corolla_tube_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating staminate_corolla_tube_width ---
# Ground truth staminate_corolla_tube_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_corolla_tube_length ---
# Ground truth pistillate_corolla_tube_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating pistillate_corolla_tube_width ---
# Ground truth pistillate_corolla_tube_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating female_corolla_lobes_length ---
# Ground truth female_corolla_lobes_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating female_corolla_lobes_width ---
# Ground truth female_corolla_lobes_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating male_corrola_lobes_length ---
# Ground truth male_corrola_lobes_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating male_corrola_lobes_width ---
# Ground truth male_corrola_lobes_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating fruit_length ---
# Ground truth fruit_length: {'exmin': nan, 'min': 3.0, 'max': 5.0, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: min=None max=None extreme_min=0.2 extreme_max=0.3
# Accurate output: False
# Justification: The numerical values and fields do not match: manual min/max are 3.0/5.0 with 'mm' unit, while automatic min/max are None with extreme min/max of 0.2/0.3. Therefore, they are not equivalent.
# Model gpt_mini_output: min=2.0 max=3.0 extreme_min=None extreme_max=None
# Accurate output: False
# Justification: The numeric values are different (manual: min=3.0, max=5.0 versus automatic: min=2.0, max=3.0) and the unit ('mm') in the manual result is missing from the automatic output.
# Model sonnet_output: min=3.0 max=5.0 extreme_min=None extreme_max=None
# Accurate output: True
# Justification: Both annotations provide the same numerical values (min=3.0, max=5.0) and represent missing extreme values (nan is equivalent to None). The omission of the unit in the automatic result is a minor formatting detail and does not affect the overall equivalence.
#
# --- Validating fruit_width ---
# Ground truth fruit_width: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': 2.0, 'unit': 'mm'}
# Model gpt_4o_output: min=None max=None extreme_min=1.0 extreme_max=2.0
# Accurate output: False
# Justification: The extreme minimum values differ: the manual annotation has it as NaN, while the automatic annotation specifies 1.0. The rest of the attributes match, but this discrepancy means they are not equivalent.
# Model gpt_mini_output: min=2.0 max=2.0 extreme_min=None extreme_max=None
# Accurate output: False
# Justification: The manually annotated value only has an extreme maximum (exmax) of 2.0 and NaNs for min and max, whereas the automatic annotation assigns 2.0 to both min and max with no extreme_max. The mismatch in fields and values makes the two results not equivalent.
# Model sonnet_output: min=2.0 max=2.0 extreme_min=None extreme_max=None
# Accurate output: False
# Justification: The manual result has NaN for min and max and sets exmax to 2.0, while the automatic result assigns min and max as 2.0 and has extreme_max as None. The values do not correspond.
#
# --- Validating fruit_diameter ---
# Ground truth fruit_diameter: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'mm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating seeds_perfruit ---
# Ground truth seeds_perfruit: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'count'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating seed_length ---
# Ground truth seed_length: {'exmin': nan, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating seed_width ---
# Ground truth seed_width: {'exmin': None, 'min': nan, 'max': nan, 'exmax': None, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
#
# --- Validating seed_diameter ---
# Ground truth seed_diameter: {'exmin': None, 'min': nan, 'max': nan, 'exmax': nan, 'unit': 'cm'}
# Model gpt_4o_output: None 	 Accurate output: True (Both NaN)
# Model gpt_mini_output: None 	 Accurate output: True (Both NaN)
# Model sonnet_output: None 	 Accurate output: True (Both NaN)
